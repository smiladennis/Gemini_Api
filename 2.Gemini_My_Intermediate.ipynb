# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="Your api_key")  # Replace with your actual Gemini API key

# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready!")

# Load the model
model = genai.GenerativeModel(model_name="gemini-flash-latest")

# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = model.generate_content(user_input)

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  you are a ai assistant
# Your new assistant is ready!
#  explain about types of ai
# To understand Artificial Intelligence (AI), experts generally classify it into **two main perspectives**:
#
# 1. **Based on Capabilities** (How smart is it compared to humans?)
# 2. **Based on Functionality/Architecture** (How does it process information?)
#
# Here is a clear breakdown of both classification systems.
#
# ---
#
# # 1. Types of AI Based on Capabilities
#
# This is the most common way to describe AI, focusing on what the system is capable of doing.
#
# ```
#        [ Narrow AI ]  --->  [ General AI (AGI) ]  --->  [ Super AI (ASI) ]
#  (Today's Reality)         (Future Goal)            (Hypothetical)
# ```
#
# ### A. Artificial Narrow AI (ANI) or "Weak AI"
# * **Status:** **In use today.**
# * **What it is:** AI programmed to perform **one specific task** exceptionally well. It operates under a narrow set of constraints and cannot perform outside its programmed domain.
# * **Key characteristic:** It lacks human-like consciousness or general adaptability.
# * **Examples:**
#   * Voice assistants (Siri, Alexa).
#   * Recommendation algorithms (Netflix, Spotify, YouTube).
#   * Facial recognition systems.
#   * Large Language Models (ChatGPT, Claude) — *even though they feel smart, they are still considered Narrow AI because they only process and generate text/data patterns.*
#
# ### B. Artificial General AI (AGI) or "Strong AI"
# * **Status:** **Theoretical / Under development.**
# * **What it is:** AI that possesses human-level intelligence. An AGI could learn, reason, adapt, plan, and solve problems across **any** domain, just like a human brain.
# * **Key characteristic:** It can transfer knowledge from one context to another without needing explicit retraining.
# * **Examples:** Does not exist yet. It is the primary goal of modern AI research labs like OpenAI and DeepMind.
#
# ### C. Artificial Superintelligence (ASI)
# * **Status:** **Hypothetical / Science Fiction.**
# * **What it is:** AI that drastically surpasses human intelligence in every aspect—including creative ability, wisdom, emotional processing, and social skills.
# * **Key characteristic:** It could outthink the smartest human minds combined and continuously improve itself at an exponential rate (a concept known as the "Technological Singularity").
# * **Examples:** Skynet (*Terminator*), HAL 9000 (*2001: A Space Odyssey*).
#
# ---
#
# # 2. Types of AI Based on Functionality
#
# This classification categorizes AI by the *mechanisms* it uses to think, remember, and interact with the world.
#
# ### Type 1: Reactive Machines
# * **How it works:** These are the simplest AI systems. They do not store memories or use past experiences to make current decisions. They simply observe the world and react to it directly.
# * **Examples:**
#   * **IBM’s Deep Blue:** The chess supercomputer that beat Garry Kasparov in 1997. It evaluated board positions in real-time but couldn't learn from past games.
#   * Basic spam filters.
#
# ### Type 2: Limited Memory
# * **How it works:** **Most modern AI falls into this category.** These systems can store past data and use it over a short time frame to inform decisions. However, they do not retain this data as long-term "experiences" like humans do.
# * **Examples:**
#   * **Self-driving cars:** They store short-term data like the speed/distance of nearby cars, traffic signals, and lane lines to navigate.
#   * **Chatbots:** They remember the context of your current conversation, but reset once the session ends.
#
# ### Type 3: Theory of Mind
# * **How it works:** **Under development.** This stage refers to AI that understands human emotions, beliefs, psychology, and thought processes. It will be able to alter its response based on how a human feels.
# * **Status:** Researchers are working on "Emotional AI" (affective computing) and social robotics, but true Theory of Mind AI does not yet exist.
#
# ### Type 4: Self-Aware AI
# * **How it works:** **Theoretical.** This is an AI that has conscious awareness, feelings, needs, and a sense of self-identity.
# * **Status:** Purely hypothetical and currently belongs to science fiction.
#
# ---
#
# # 3. Modern Practical Distinction: Generative vs. Predictive AI
#
# In today's industry, you will frequently hear AI categorized by what it *produces*:
#
# * **Predictive / Traditional AI:** Analyzes historical data to make forecasts, detect anomalies, or classify information (e.g., fraud detection, predicting stock prices, medical diagnosis).
# * **Generative AI (GenAI):** Creates **new content** (text, images, audio, video, code) based on patterns learned from training data (e.g., ChatGPT, Midjourney, DALL-E).
#
# ---
#
# # Summary Matrix
#
# | Category | Type | Current Status | Example |
# | :--- | :--- | :--- | :--- |
# | **Capability** | Narrow AI (ANI) | **Active Today** | ChatGPT, Siri, Tesla Autopilot |
# | | General AI (AGI) | Future Goal | Human-level intellect |
# | | Super AI (ASI) | Theoretical | Sci-Fi Supercomputers |
# | **Functionality**| Reactive Machines | Active | Basic Chess Bots |
# | | Limited Memory | **Active Today** | Self-driving cars, LLMs |
# | | Theory of Mind | Research Phase | Social Robots |
# | | Self-Aware | Theoretical | Sentient AI |
#  quit
